# %% [markdown]
# <a href="https://colab.research.google.com/github/meg418/DevOpsCodeDemo/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = ['rama','sita','krishna', 'radha']
age =   [10,     20,      40,         60]

# %%
type(names)
# Out:
# list

# %%
a=names[0]
print(a)
len(names)
# Out:
# rama
# 4

# %%
names1=names[:-1]
names1
# Out:
# ['rama', 'sita', 'krishna']

# %%
numbers=list(('meghaa'))
numbers
# Out:
# ['m', 'e', 'g', 'h', 'a', 'a']

# %%
numbers.append(222)
numbers
# Out:
# ['m', 'e', 'g', 'h', 'a', 'a', 222, 222, 222, 222, 222]

# %%
numbers.remove(222)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3169813711.py in <cell line: 0>()
# ----> 1 numbers.remove(222)
#
# ValueError: list.remove(x): x not in list

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers.insert(0,222)
numbers
# Out:
# [222, 222, 1, 2, 3, 4, 5, 222]

# %%
numbers.extend([1,2,3,4,5])

# %%
numbers
# Out:
# [222, 222, 1, 2, 3, 4, 5, 222, 1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [222, 1, 2, 3, 4, 5, 222, 1, 2, 3, 4, 5]

# %%
numbers.remove(222)

# %%
numbers.pop(6)
# Out:
# 222

# %%
numbers.clear()

# %%
numbers
# Out:
# []

# %%
numbers.extend(list(range(6)))
numbers
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
print(3 in numbers)
print(88 in numbers)
# Out:
# True
# False

# %%
print(names,age)
# Out:
# ['rama', 'sita', 'krishna', 'radha'] [10, 20, 40, 60]

# %%
names
# Out:
# ['rama', 'sita', 'krishna', 'radha']

# %%
for name in names:
  print(name.capitalize()+'123')
# Out:
# Rama123
# Sita123
# Krishna123
# Radha123

# %%
numbers
# Out:
# ['m', 'e', 'g', 'h', 'a', 'a']

# %%
a=[1,2,3,4,4]
print(a.count(4))
# Out:
# 2

# %%
numbers
# Out:
# ['m', 'e', 'g', 'h', 'a', 'a']

# %%
numbers.index('h')
# Out:
# 3

# %%
f=numbers.copy()
f
# Out:
# ['m', 'e', 'g', 'h', 'a', 'a']

# %%
numbers.append(10)
numbers
# Out:
# ['m', 'e', 'g', 'h', 'a', 'a', 10]

# %%
f
# Out:
# ['m', 'e', 'g', 'h', 'a', 'a']

# %%
f=numbers
f
# Out:
# ['m', 'e', 'g', 'h', 'a', 'a', 10]

# %%
numbers
# Out:
# ['m', 'e', 'g', 'h', 'a', 'a', 10]

# %%
numbers.insert(0,13)
numbers
# Out:
# [13, 13, 'm', 'e', 'g', 'h', 'a', 'a', 10]

# %%
f
# Out:
# [13, 13, 'm', 'e', 'g', 'h', 'a', 'a', 10]

# %%
names = ['rama','sita','krishna', 'radha']
ages =   [10,     20,      40,         60]

# %%
for n in names:
  print(n)
# Out:
# rama
# sita
# krishna
# radha

# %%
for a in ages:
  print(a)
# Out:
# 10
# 20
# 40
# 60

# %%
x = 'megha shyuam g'

# %%
x.split()
# Out:
# ['megha', 'shyuam', 'g']

# %%
list(zip(names,ages))
# Out:
# [('rama', 10), ('sita', 20), ('krishna', 40), ('radha', 60)]

# %%
for n in ages:
  n=n**2
  print(n)
# Out:
# 100
# 400
# 1600
# 3600

# %%
list(range(1,5))
# Out:
# [1, 2, 3, 4]

# %%
tejdeep=dict()

# %%
tejdeep['megha']=30
tejdeep
# Out:
# {'megha': 30}

# %%
tejdeep['tej']=15
tejdeep
# Out:
# {'megha': 30, 'tej': 15}

# %%
tejdeep.keys()
# Out:
# dict_keys(['megha', 'tej'])

# %%
tejdeep.values()
# Out:
# dict_values([30, 15])

# %%
tejdeep.items()
# Out:
# dict_items([('megha', 30), ('tej', 15)])

# %%
for k  in tejdeep.values():
  print(k)
# Out:
# 30
# 15

# %%
emps_data = '''
tom 1 tom@abc.com 1121 1234
dick 2 dick@abc.com 1122 1235
harry 3 harry@abc.com 1123 1236
'''

# %%
emp_dict={}

# %%
emp_dict['tom']=[1, 'tom@abc.com', 1121, 1234]
emp_dict
# Out:
# {'tom': [1, 'tom@abc.com', 1121, 1234]}

# %%
emp1='tom 1 tom@abc.com 1121 1234'.split()[0]
emp1
# Out:
# 'tom'

# %%
emps_data.split('\n')
# Out:
# ['',
#  'tom 1 tom@abc.com 1121 1234',
#  'dick 2 dick@abc.com 1122 1235',
#  'harry 3 harry@abc.com 1123 1236',
#  '']

# %%
emps_data.splitlines()
# Out:
# ['',
#  'tom 1 tom@abc.com 1121 1234',
#  'dick 2 dick@abc.com 1122 1235',
#  'harry 3 harry@abc.com 1123 1236']

# %%
emps_data.strip().splitlines()
# Out:
# ['tom 1 tom@abc.com 1121 1234',
#  'dick 2 dick@abc.com 1122 1235',
#  'harry 3 harry@abc.com 1123 1236']

# %%
for emp in emps_data.strip().splitlines():
  emp=emp.split()
  emp_dict[emp[0]]=emp[1:]
emp_dict
# Out:
# {'tom': ['1', 'tom@abc.com', '1121', '1234'],
#  'dick': ['2', 'dick@abc.com', '1122', '1235'],
#  'harry': ['3', 'harry@abc.com', '1123', '1236']}
